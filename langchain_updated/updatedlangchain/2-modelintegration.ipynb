# %% [markdown]
# ### Models integration with openai , gemini , groq .

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("groq:llama-3.3-70b-versatile")
model
# Out:
# ChatGroq(output_version=None, profile={'max_input_tokens': 131072, 'max_output_tokens': 32768, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x110e2de80>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x110e2e900>, model_name='llama-3.3-70b-versatile', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)

# %%
## invoke the model
response = model.invoke("Hello, how are you?") 
response
# Out:
# AIMessage(content="Hello, I'm doing well, thank you for asking. I'm a large language model, so I don't have feelings or emotions like humans do, but I'm always happy to chat and help with any questions or topics you'd like to discuss. How about you? How's your day going so far?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 64, 'prompt_tokens': 41, 'total_tokens': 105, 'completion_time': 0.137529029, 'completion_tokens_details': None, 'prompt_time': 0.011373418, 'prompt_tokens_details': None, 'queue_time': 0.163265991, 'total_time': 0.148902447}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019e93aa-03d0-7211-a269-34ff5469a179-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 64, 'total_tokens': 105})

# %%
response.content
# Out:
# "Hello, I'm doing well, thank you for asking. I'm a large language model, so I don't have feelings or emotions like humans do, but I'm always happy to chat and help with any questions or topics you'd like to discuss. How about you? How's your day going so far?"

# %% [markdown]
# ### Google Gemini Model integration
# two ways
# 1) using init chat model
# 2) using  genai chat model directly
#
#
# ```python

# %%
import os
from langchain.chat_models import init_chat_model
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

model = init_chat_model("google_genai:gemini-2.5-flash-lite")
response = model.invoke("What do parrot talk?")
response.content
# Out:
# 'Parrots are famous for their ability to mimic sounds, and the most common thing they "talk" is **human speech**.\n\nHowever, it\'s important to understand what "talk" means in the context of parrots:\n\n*   **Mimicry, not understanding:** Parrots don\'t truly understand the meaning of the words they repeat in the way humans do. They learn to associate sounds with specific contexts, people, or actions. For example, a parrot might learn to say "hello" when someone enters the room or "goodbye" when they leave.\n*   **Vocal learning:** This ability to mimic is a form of vocal learning, which is quite advanced. They can pick up on the nuances of tone, pitch, and even accent from the sounds they hear.\n*   **Variety of sounds:** While human speech is the most impressive, parrots can also mimic a wide range of other sounds they hear in their environment, such as:\n    *   **Other bird calls:** They might mimic the sounds of other birds, even if those birds aren\'t in their immediate vicinity.\n    *   **Household noises:** Doorbells, telephones, alarms, microwave beeps, even the sound of a flushing toilet!\n    *   **Animal sounds:** Dogs barking, cats meowing, etc.\n    *   **Music:** They can sometimes sing or hum melodies.\n\n**What influences what a parrot talks?**\n\n*   **Species:** Some parrot species are more renowned for their talking abilities than others. African Grey Parrots are particularly famous for their extensive vocabularies and ability to use words contextually. Amazona parrots and some conures are also good talkers.\n*   **Individual personality:** Just like humans, some individual parrots are more inclined to talk than others, even within the same species.\n*   **Environment and interaction:** Parrots that are exposed to more speech and have more interaction with humans are more likely to learn to talk. They are social creatures and often learn to "talk" to communicate and get attention.\n*   **Training and encouragement:** While some parrots will learn on their own, consistent and positive reinforcement can help them learn new words and phrases.\n\n**In summary, parrots "talk" by mimicking the sounds they hear, most notably human speech. They are incredibly adept at vocal learning and can pick up a vast array of sounds, using them in ways that can be surprisingly context-appropriate, even if they don\'t grasp the semantic meaning.**'

# %% [markdown]
# using google genai model
# ```

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
response = model.invoke("What do parrot talk?")
response.content
# Out:
# 'Parrots are famous for their ability to "talk," which means they can mimic sounds they hear, including human speech. However, it\'s important to understand what "talking" means for a parrot:\n\n*   **Mimicry, Not Understanding:** Parrots don\'t understand the meaning of the words they say in the same way humans do. They are highly intelligent birds, and they can learn to associate sounds with specific contexts or rewards, but they don\'t have the cognitive capacity for true language comprehension.\n\n*   **Vocalization and Sounds:** What we perceive as "talking" is actually their ability to produce a wide range of sounds. This includes:\n    *   **Human Speech:** They can accurately replicate the pitch, tone, and rhythm of words and phrases they hear frequently.\n    *   **Other Sounds:** They can also mimic other noises from their environment, such as doorbells, phone rings, the sound of a microwave, or even other animal noises.\n    *   **Their Own Calls:** Parrots have their own natural vocalizations, which they use for communication within their flock (or with their human "flock"). These can include squawks, whistles, clicks, and chirps.\n\n*   **Reasons for Mimicry:** Parrots mimic for several reasons:\n    *   **Social Bonding:** In the wild, parrots are highly social creatures. Mimicry is a way for them to bond with their flock members and feel like part of the group. When they live with humans, they often see their owners as their flock and will try to mimic their sounds to integrate.\n    *   **Attention and Interaction:** They learn that making certain sounds, especially human words, gets them attention from their owners. This can lead to them repeating those sounds to get more interaction.\n    *   **Curiosity and Playfulness:** Parrots are intelligent and curious. They enjoy learning new sounds and experimenting with their vocal abilities.\n    *   **Boredom:** A bored parrot might start mimicking sounds simply to entertain itself.\n\n**Which parrots talk the most?**\n\nWhile many parrot species can mimic, some are known for being particularly adept at it:\n\n*   **African Grey Parrots:** Often considered the "Einstein" of the parrot world for their remarkable ability to learn and use a large vocabulary, and sometimes even associate words with objects or actions.\n*   **Amazon Parrots:** Many Amazon species are excellent talkers and can have very clear voices.\n*   **Budgerigars (Budgies):** Despite their small size, budgies can learn an impressive number of words and phrases, often in a very rapid and sometimes "chattering" way.\n*   **Indian Ringnecks:** These parrots can be excellent mimics and often have a very clear, distinct voice.\n*   **Cockatoos:** While known for their intelligence and personality, some cockatoo species can also be good talkers, though their vocalizations can sometimes be louder and more piercing.\n\n**In summary, when parrots "talk," they are mimicking sounds they hear, primarily human speech, as a form of social interaction, attention-seeking, or simply for enjoyment.**'

# %% [markdown]
# ### Streaming And Batch
#
# ## Streaming
#
# Most models can stream their output content while it is being generated. By displaying output progressively, streaming significantly improves user experience, particularly for longer responses. Calling stream() returns an iterator that yields output chunks as they are produced. You can use a loop to process each chunk in real-time:

# %%
model.invoke("Write me a 200 words paragraph on Artificial Intelligence")
# Out:
# AIMessage(content="Artificial Intelligence (AI) is revolutionizing our world by enabling machines to perform tasks that typically require human intelligence. This encompasses a broad spectrum of capabilities, from learning and problem-solving to perception and decision-making. Machine learning, a core component of AI, allows systems to improve their performance over time through exposure to data, rather than explicit programming. Deep learning, a subset of machine learning, utilizes complex neural networks to process vast amounts of information, leading to breakthroughs in areas like image recognition and natural language processing. AI is already integrated into our daily lives, powering virtual assistants, recommendation engines, and autonomous vehicles. As AI continues to advance, its potential applications are boundless, promising to transform industries, enhance human capabilities, and solve some of humanity's most pressing challenges. However, its rapid development also raises important ethical considerations regarding bias, privacy, and the future of work.", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e93c4-cfcf-7963-bdbe-22a8647911d1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 176, 'total_tokens': 189, 'input_token_details': {'cache_read': 0}})

# %%
for chunk in model.stream("Write me a 200 words paragraph on Artificial Intelligence"):
    print(chunk.text, end="|", flush=True)
# Out:
# Artificial Intelligence (AI) is| a transformative field of computer science focused on creating systems capable of performing tasks that typically| require human intelligence. This encompasses a broad spectrum of capabilities, including learning, problem-solving, decision-making, perception, and natural language understanding. AI systems learn from vast amounts of data, identifying patterns and making predictions or taking actions without explicit| programming for every scenario. From virtual assistants and recommendation engines to self-driving cars and advanced medical diagnostics, AI is rapidly integrating into our daily lives, enhancing efficiency, and unlocking new possibilities. While its potential is immense, AI also raises important ethical considerations| regarding bias, job displacement, and privacy, prompting ongoing discussions about responsible development and deployment.||

# %%
model.invoke("Why do parrots have colorful feathers?")
# Out:
# AIMessage(content="Parrots have colorful feathers for a variety of fascinating reasons, primarily related to **survival and reproduction**. Here's a breakdown of the main factors:\n\n**1. Communication and Social Signaling:**\n\n* **Species Recognition:** Bright, distinct colors and patterns help parrots identify members of their own species, which is crucial for finding mates, forming flocks, and avoiding interbreeding.\n* **Mate Selection:** In many species, the vibrancy and intensity of certain colors can signal a parrot's health, age, and genetic quality to potential mates. A more colorful bird might be seen as a more desirable partner.\n* **Social Status and Hierarchy:** Within a flock, color patterns can sometimes indicate dominance or social standing, influencing interactions and access to resources.\n* **Mood and Emotional Display:** While not as nuanced as human facial expressions, changes in feather erection and subtle color shifts can communicate a parrot's mood, such as excitement, fear, or aggression.\n* **Alarm Signals:** In some cases, specific bright colors might be used to signal danger to other members of the flock.\n\n**2. Camouflage and Concealment:**\n\n* **Blending with the Environment:** While many parrots are strikingly colorful, their plumage often allows them to blend remarkably well with the vibrant foliage of their tropical and subtropical habitats. Greens are common for blending with leaves, and other colors might mimic flowers, fruits, or dappled sunlight.\n* **Predator Evasion:** Effective camouflage makes it harder for predators to spot them, both when they are resting and when they are foraging.\n\n**3. Thermoregulation:**\n\n* **Heat Absorption and Dissipation:** Darker feathers absorb more sunlight and can help parrots stay warm in cooler conditions or at higher altitudes. Lighter or iridescent feathers might reflect more sunlight, helping them to stay cool in hot environments.\n* **Feather Structure:** The structure of the feathers themselves, not just their color, can play a role in insulation and air flow.\n\n**4. Protection from Sunlight:**\n\n* **UV Protection:** Some pigments in feathers can act as a natural sunscreen, protecting the parrot's skin from harmful ultraviolet (UV) radiation, especially in exposed tropical environments.\n\n**5. Pigments and Structural Colors:**\n\nIt's important to understand *how* parrots achieve their colors:\n\n* **Pigments:** These are chemical compounds that absorb certain wavelengths of light and reflect others.\n    * **Melanins:** Produce blacks, browns, grays, and some muted reds and yellows.\n    * **Porphyrins:** Produce reds, oranges, and greens. These are less common and can be degraded by sunlight.\n* **Structural Colors:** These are created by the physical structure of the feather barbules. Light waves interact with the microscopic structures, causing interference and scattering that produces iridescent blues, greens, and violets. These colors can change depending on the angle of light.\n\n**Evolutionary Advantage:**\n\nUltimately, the development of colorful plumage in parrots is a result of **natural selection**. Individuals with feather colors that provided an advantage in communication, survival, or reproduction were more likely to pass on their genes to the next generation. Over time, this led to the incredible diversity of colors we see in parrots today.\n\nIn summary, parrot coloration is a complex interplay of evolutionary pressures, serving vital roles in their social lives, their ability to survive in their environment, and their reproductive success.", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e93c7-98fd-7d33-8294-8451bdd54142-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 700, 'total_tokens': 708, 'input_token_details': {'cache_read': 0}})

# %%
for chunk in model.stream("Why do parrots have colorful feathers?"):
    print(chunk.text, end="|", flush=True)
# Out:
# Parrots have colorful feathers for| a variety of reasons, and it's a fascinating interplay of **evolutionary pressures|, communication, and survival strategies.** Here's a breakdown of the main factors:
#
# **1. Communication and Social Signaling:**
#
# * **Mate Attraction and Selection:** This is a primary driver for vibrant colors in many species. Bright,| well-maintained plumage can signal a parrot's health, vitality, and good genes to potential mates. Males of many species display their colors prominently during courtship rituals to impress females.
# * **Species and Individual Recognition:** The specific patterns and combinations| of colors can help parrots identify members of their own species, as well as individuals within their flock. This is crucial for social cohesion, recognizing family members, and avoiding confusion with other birds.
# * **Status and Dominance:** In some parrot| species, the intensity or specific arrangement of certain colors might indicate an individual's social status or dominance within the group. This can help reduce aggression and establish a clear pecking order.
# * **Emotional Expression:** While not as overt as in| some other animals, subtle changes in feather coloration or iridescence might be linked to a parrot's emotional state, such as excitement or agitation.
#
# **2. Camouflage and Predator Avoidance:**
#
# * **Habitat Blending:** While we| often associate colorful parrots with tropical rainforests, many species have evolved colors that help them blend into their specific environments. For example, green parrots are excellent at hiding amongst foliage. Red and yellow can mimic fruits or flowers, making them harder for| predators to spot.
# * **Disruptive Coloration:** Bold patterns and contrasting colors can break up the outline of a parrot's body, making it more difficult for predators to perceive it as a single, cohesive shape. This is particularly effective| when they are perched amongst dappled sunlight and shadows.
# * **Warning Signals (Aposematism):** In some cases, extremely bright and conspicuous colors can serve as a warning to predators that the parrot is toxic or unpalatable. However|, this is less common in parrots compared to insects or amphibians.
#
# **3. Thermoregulation:**
#
# * **Heat Absorption and Dissipation:** While not the primary reason, feather color can play a minor role in thermoregulation.| Darker feathers absorb more sunlight and can help birds stay warm in cooler environments, while lighter or iridescent feathers might reflect more sunlight, helping to prevent overheating in hot climates.
#
# **4. Pigments and Structural Coloration:**
#
# The vibrant| colors of parrot feathers are a result of two main mechanisms:
#
# * **Pigments:** These are chemical compounds that absorb certain wavelengths of light and reflect others.
#     * **Melanins:** Produce blacks, browns, and some muted| grays.
#     * **Carotenoids:** These are obtained from their diet (fruits, vegetables, seeds) and produce reds, oranges, and yellows. This is why a parrot's diet is crucial for maintaining these vibrant colors.
# *| **Structural Coloration:** This is caused by the microscopic structure of the feather barbules. These structures interact with light in a way that produces iridescent blues, greens, and violets. This type of coloration can change depending on the angle of light.|
#
# **In summary, the colorful plumage of parrots is a multifaceted adaptation that serves crucial roles in their survival and reproductive success. It's a beautiful testament to the power of natural selection, showcasing how evolution has sculpted these birds into the visually| stunning creatures they are today.**||

# %% [markdown]
# ## BATCH

# %% [markdown]
# Batching a collection of independent requests to a model can significantly improve performance and reduce costs, as the processing can be done in parallel:

# %%
responses = model.batch([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
])
for response in responses:
    print(response)
# Out:
# content="Parrots have colorful feathers for a variety of reasons, and it's not a single, simple answer. The vibrant hues serve multiple important functions in their lives, primarily revolving around **communication and survival**. Here are the main reasons:\n\n**1. Mate Attraction and Sexual Selection:**\n\n*   **Visual Signals:** In many parrot species, bright and varied plumage is a key indicator of a bird's health, age, and genetic quality. Potential mates use these colors to assess the suitability of a partner. Brighter, more intense colors often signal a healthy individual with good foraging abilities and resistance to parasites.\n*   **Species Recognition:** With so many parrot species in existence, vibrant colors can help them quickly and easily identify members of their own species. This is crucial for successful mating and avoiding hybridization.\n*   **Courtship Displays:** The colors can be highlighted and displayed during courtship rituals, further emphasizing the bird's attractiveness to potential mates.\n\n**2. Social Signaling and Communication:**\n\n*   **Mood and Emotion:** While not as overt as in some other animals, subtle changes in feather position and coloration can sometimes indicate a parrot's mood, such as aggression, excitement, or fear.\n*   **Group Cohesion:** In social species, the uniformity of color within a flock can help maintain group cohesion and facilitate communication within the flock. They can easily spot and keep track of each other in dense foliage.\n*   **Status and Dominance:** In some cases, specific color patterns or the intensity of certain colors might be linked to social status within a flock.\n\n**3. Camouflage and Predator Evasion:**\n\n*   **Blending with the Environment:** While we often associate bright colors with being conspicuous, many parrots live in environments with a riot of colors, such as lush rainforests. Their vibrant plumage can actually help them blend in with the flowers, fruits, and foliage of their habitat, making them harder for predators to spot.\n*   **Disruptive Coloration:** Complex patterns and contrasting colors can break up the outline of the bird, making it more difficult for predators to recognize them as prey.\n\n**4. Thermoregulation (Less Significant, but Possible):**\n\n*   **Absorption of Sunlight:** Darker pigments can absorb more sunlight, which could help some parrots in cooler environments stay warm. Conversely, lighter colors might reflect more sunlight, helping to prevent overheating in hot climates. However, this is generally considered a less significant factor compared to communication and camouflage.\n\n**5. Diet and Pigment Production:**\n\n*   **Carotenoids:** The vibrant reds, oranges, and yellows in parrot feathers are often derived from pigments called carotenoids. These pigments are obtained from their diet, particularly from fruits, seeds, and flowers. The ability to metabolize and deposit these carotenoids in their feathers is an indicator of their foraging success and overall health.\n*   **Melanins:** Blues, greens, and blacks are typically produced by melanin pigments, which are synthesized by the parrot itself.\n\n**In summary, the colorful feathers of parrots are a testament to the power of natural selection. They are not just for show; they are a complex and vital tool for survival, reproduction, and social interaction in their diverse and often challenging environments.**" additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019e93cd-6f93-72a3-b0fa-3d6f3700aa95-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 8, 'output_tokens': 667, 'total_tokens': 675, 'input_token_details': {'cache_read': 0}}
# content='Airplanes fly due to a clever interplay of physics, primarily involving the shape of their wings and the way air flows around them. Here\'s a breakdown of the key principles:\n\n**1. The Four Forces of Flight:**\n\nImagine an airplane in the air. There are four main forces acting on it:\n\n*   **Lift:** The upward force that opposes gravity. This is the magical force that keeps the plane in the sky.\n*   **Weight (or Gravity):** The downward force pulling the plane towards the Earth.\n*   **Thrust:** The forward force generated by the engines that propels the plane through the air.\n*   **Drag:** The backward force that opposes thrust, caused by air resistance.\n\nFor an airplane to fly, **lift must be greater than or equal to weight**, and **thrust must be greater than or equal to drag**.\n\n**2. The Magic of the Wing: Generating Lift (Bernoulli\'s Principle and Newton\'s Third Law)**\n\nThis is where the airplane\'s design, particularly its wings, becomes crucial. Airplane wings have a special shape called an **airfoil**.\n\n*   **The Airfoil Shape:** An airfoil is typically curved on the top and flatter on the bottom.\n\n*   **Bernoulli\'s Principle:** As the airplane moves forward, air flows over and under the wings. Because of the curved top, the air traveling over the top of the wing has to travel a longer distance than the air traveling under the bottom of the wing in the same amount of time. To cover this longer distance, the air on top must move faster.\n    *   **Bernoulli\'s principle states that as the speed of a fluid (like air) increases, its pressure decreases.**\n    *   Therefore, the faster-moving air on top of the wing creates an area of lower pressure compared to the slower-moving air on the bottom of the wing, which has higher pressure.\n    *   This **pressure difference** results in an upward force pushing on the wing – this is **lift**.\n\n*   **Newton\'s Third Law of Motion (Action-Reaction):** This law also plays a role. As the wing moves through the air, its angle (called the **angle of attack**) causes the air to be deflected downwards.\n    *   **Newton\'s third law states that for every action, there is an equal and opposite reaction.**\n    *   The action is the wing pushing air downwards. The reaction is the air pushing the wing upwards – contributing to **lift**.\n\n**3. Thrust: The Engine\'s Role**\n\n*   **Propellers:** In older or smaller aircraft, propellers are used. They are essentially rotating airfoils that "screw" their way through the air, pushing it backward and thus generating forward thrust.\n*   **Jet Engines:** In modern jetliners, jet engines work by taking in large amounts of air, compressing it, mixing it with fuel, igniting it, and expelling the hot gases out the back at high speed. This expulsion of gas creates a powerful backward force, which, by Newton\'s third law, results in an equal and opposite forward thrust.\n\n**4. Overcoming Drag**\n\n*   **Streamlined Design:** Airplanes are designed to be as streamlined as possible to minimize drag. This means smooth surfaces, rounded edges, and a shape that allows air to flow around it efficiently.\n*   **Wing and Fuselage Shape:** The overall shape of the aircraft is designed to cut through the air with minimal resistance.\n\n**In Summary: The Process of Flight**\n\n1.  **Thrust is generated by the engines**, pushing the airplane forward.\n2.  As the airplane moves forward, **air flows over and under the wings**.\n3.  The **airfoil shape of the wings** causes the air on top to move faster than the air on the bottom.\n4.  This speed difference creates a **pressure difference** (lower pressure on top, higher pressure on bottom), resulting in **lift**.\n5.  Simultaneously, the angle of the wings deflects air downwards, creating an **upward reaction force**.\n6.  When the **lift generated is greater than the airplane\'s weight**, the airplane rises into the air.\n7.  The airplane\'s speed is maintained by **thrust overcomi ...
# content='Quantum computing is a revolutionary new type of computing that leverages the principles of quantum mechanics to perform calculations. Unlike classical computers that store information as bits representing either 0 or 1, quantum computers use **qubits**.\n\nHere\'s a breakdown of the key concepts:\n\n**1. Qubits: The Building Blocks of Quantum Computing**\n\n*   **Superposition:** A qubit can exist in a superposition of both 0 and 1 simultaneously. Imagine a coin spinning in the air – it\'s neither heads nor tails until it lands. A qubit is like that spinning coin, holding a probability of being 0 and a probability of being 1. This allows quantum computers to represent and process vastly more information than classical bits.\n*   **Entanglement:** This is a phenomenon where two or more qubits become linked in such a way that their fates are intertwined, regardless of the distance separating them. If you measure the state of one entangled qubit, you instantly know the state of the other. This correlation allows for powerful computational operations.\n\n**2. How Quantum Computers Work (in a Simplified Way)**\n\nInstead of executing instructions sequentially like classical computers, quantum computers perform operations on qubits in superposition and entanglement. These operations are called **quantum gates**.\n\n*   **Quantum Gates:** These are analogous to logic gates in classical computers (like AND, OR, NOT) but operate on qubits. They manipulate the probabilities and correlations of the qubits.\n*   **Measurement:** When you "read out" the result of a quantum computation, the qubits collapse from their superposition into a definite classical state (0 or 1). The key is that the quantum computation is designed so that the desired answer has a much higher probability of being measured than incorrect answers.\n\n**3. What Makes Quantum Computing So Powerful?**\n\nThe ability of qubits to be in superposition and to be entangled allows quantum computers to explore many possibilities simultaneously. This leads to an exponential speedup for certain types of problems that are intractable for even the most powerful classical supercomputers.\n\n**4. Potential Applications of Quantum Computing**\n\nQuantum computing is still in its early stages, but its potential applications are vast and transformative:\n\n*   **Drug Discovery and Materials Science:** Simulating the behavior of molecules and materials at the atomic level, leading to the development of new drugs, catalysts, and advanced materials.\n*   **Cryptography:** Breaking current encryption methods (like RSA) which rely on the difficulty of factoring large numbers. However, quantum computers could also be used to develop new, quantum-resistant encryption.\n*   **Optimization Problems:** Solving complex problems like optimizing logistics, financial portfolios, and traffic flow more efficiently.\n*   **Artificial Intelligence and Machine Learning:** Enhancing AI algorithms for tasks like pattern recognition, data analysis, and complex simulations.\n*   **Scientific Research:** Advancing our understanding of fundamental physics, cosmology, and other scientific fields.\n\n**5. Challenges and Limitations**\n\nDespite its promise, quantum computing faces significant challenges:\n\n*   **Decoherence:** Qubits are extremely sensitive to their environment. Even small disturbances can cause them to lose their quantum properties (decohere), leading to errors.\n*   **Error Correction:** Developing robust methods for detecting and correcting errors in quantum computations is crucial.\n*   **Scalability:** Building quantum computers with a large number of stable and interconnected qubits is a major engineering feat.\n*   **Algorithm Development:** Designing efficient quantum algorithms for specific problems is an ongoing area of research.\n*   **Cost and Accessibility:** Quantum computers are currently very expensive and complex to build and operate.\n\n**In essence, quantum computing ...

# %%
model.batch(
    ["Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"],
    config={
        'max_concurrency': 5,  # Limit to 5 parallel calls
    }
)
# Out:
# [AIMessage(content="Parrots have colorful feathers for a variety of reasons, and it's a fascinating interplay of **evolution, communication, and survival**. Here are the main drivers behind their vibrant plumage:\n\n**1. Communication and Social Signaling:**\n\n* **Mate Attraction and Selection:** This is arguably the most significant reason. In many parrot species, bright and varied colors are indicators of health, vitality, and good genes. Males with the most striking plumage are often more successful in attracting females and passing on their genes. The specific colors and patterns can also be unique to a species, helping individuals recognize and identify potential mates.\n* **Species Recognition:** The distinct color patterns act as visual cues, allowing parrots to distinguish between individuals of their own species and those of other species. This is crucial for avoiding hybridization and for maintaining social bonds within a flock.\n* **Social Status and Dominance:** In some species, the intensity or specific arrangement of colors can signal an individual's dominance or social rank within the flock. This can influence access to resources like food and nesting sites.\n* **Alarm Calls and Warning Signals:** While not as common as other signals, certain bright patches of color might be used in conjunction with alarm calls to startle predators or signal danger to other flock members.\n\n**2. Camouflage (Surprisingly!):**\n\n* **Blending with the Environment:** While we often think of parrots as brightly colored, many species inhabit lush, tropical rainforests. The vibrant greens, blues, and yellows can actually help them blend in with the foliage, flowers, and fruits of their environment, making it harder for predators to spot them.\n* **Disruptive Coloration:** The irregular patches and patterns of color can break up the parrot's outline, making it more difficult for predators to recognize its shape.\n\n**3. Melanin and Pigments:**\n\n* **Structural Colors:** Many of a parrot's colors are not due to pigments but are created by the way light interacts with the microscopic structure of their feathers. Tiny structures within the feather barbules scatter and reflect light, producing vibrant blues, greens, and iridescence. This is similar to how a soap bubble or a peacock's feather gets its color.\n* **Pigmentary Colors:** Other colors, like reds, oranges, and yellows, are produced by pigments called **carotenoids**. Parrots obtain these pigments from the plants they eat. Therefore, a parrot's diet directly influences the richness and intensity of these colors.\n\n**4. Thermoregulation (Less Significant, but Possible):**\n\n* **Heat Absorption/Reflection:** While not a primary driver, the color of feathers can play a minor role in thermoregulation. Darker feathers absorb more heat, while lighter feathers reflect more. In some species, this might offer a slight advantage in regulating body temperature in different environments.\n\n**In summary, the colorful feathers of parrots are a result of:**\n\n* **Sexual selection:** The need to attract mates and reproduce.\n* **Social communication:** Identifying individuals, signaling status, and recognizing their own kind.\n* **Environmental adaptation:** Camouflage in their often vibrant habitats.\n* **The physics of light and the chemistry of pigments:** Creating the stunning visual displays.\n\nIt's a testament to the power of evolution that these birds have evolved such diverse and spectacular plumage, making them some of the most visually striking creatures on Earth.", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e93cf-733f-7d43-a670-6dc2ee1c03dc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 695, 'total_tokens': 703, 'input_token_details': {'cache_read': 0}}),
#  AIMessage(content="The magic of flight in airplanes is a remarkable feat of engineering, primarily achieved through the interplay of four fundamental forces: **lift, weight, thrust, and drag.**\n\nLet's break down each of these:\n\n**1. Lift: The Upward Force**\n\nThis is the most crucial force that counteracts gravity and keeps the airplane in the air. Lift is generated by the **wings** of the airplane, and the key principle behind it is **Bernoulli's Principle** and Newton's Third Law of Motion.\n\n*   **Airfoil Shape:** Airplane wings are not flat. They have a special shape called an **airfoil**. This shape is typically curved on the top and flatter on the bottom.\n*   **Airflow and Speed Difference:** As the airplane moves forward, air flows over and under the wings. Because of the curved upper surface, the air traveling over the top has to travel a longer distance than the air traveling under the bottom in the same amount of time. To cover this longer distance, the air on top must move **faster**.\n*   **Pressure Difference (Bernoulli's Principle):** Bernoulli's Principle states that as the speed of a fluid (like air) increases, its pressure decreases. Therefore, the faster-moving air over the top of the wing creates **lower pressure** than the slower-moving air under the bottom of the wing, which has **higher pressure**.\n*   **Upward Push:** This pressure difference creates an upward force pushing the wing from the high-pressure area below to the low-pressure area above. This upward force is **lift**.\n*   **Angle of Attack:** The angle at which the wing meets the oncoming air (the **angle of attack**) also plays a significant role. A slightly upward angle of attack deflects more air downwards, which, by Newton's Third Law (for every action, there is an equal and opposite reaction), results in an upward force on the wing.\n\n**2. Weight: The Downward Force**\n\nThis is simply the force of gravity pulling the airplane and everything inside it down towards the Earth. To fly, the airplane's lift must be greater than or equal to its weight.\n\n**3. Thrust: The Forward Force**\n\nThrust is the force that propels the airplane forward through the air. It is generated by the **engines**, which can be:\n\n*   **Jet Engines:** These engines work by sucking in air, compressing it, mixing it with fuel, igniting the mixture, and then expelling the hot gases at high speed out the back. This expulsion of gas creates a powerful forward thrust (Newton's Third Law again).\n*   **Propeller Engines:** These engines use rotating blades (propellers) to push air backward. This backward movement of air creates a forward thrust on the airplane.\n\n**4. Drag: The Backward Force**\n\nDrag is the force that opposes the airplane's forward motion. It's essentially the resistance of the air. There are two main types of drag:\n\n*   **Form Drag (Pressure Drag):** This is due to the shape of the airplane and how it disrupts the airflow. A more streamlined shape reduces form drag.\n*   **Skin Friction Drag:** This is caused by the friction between the air and the surface of the airplane.\n\nTo maintain a constant speed, thrust must overcome drag. To accelerate, thrust must be greater than drag.\n\n**How These Forces Work Together for Flight:**\n\n*   **Takeoff:** During takeoff, the engines generate a significant amount of thrust, pushing the airplane forward at increasing speed. As the speed increases, the wings generate more lift. When the lift generated becomes greater than the airplane's weight, the airplane becomes airborne.\n*   **Cruising:** Once at cruising altitude and speed, the pilot adjusts the engine power and control surfaces so that lift equals weight and thrust equals drag. This allows the airplane to maintain a constant altitude and speed.\n*   **Climbing:** To climb, the pilot increases thrust and/or increases the angle of attack of the wings to generate more lift than weight.\n*   **Descending:** To descend, the pilot reduces thrust  ...
#  AIMessage(content="Quantum computing is a revolutionary new type of computing that leverages the principles of quantum mechanics to perform calculations. Unlike classical computers that use bits to represent information as either a 0 or a 1, quantum computers use **qubits**.\n\nHere's a breakdown of what makes quantum computing so special:\n\n**1. Qubits: The Building Blocks of Quantum Computing**\n\n*   **Superposition:** This is the key difference. A qubit can exist in a state of **both 0 and 1 simultaneously**. Imagine a coin spinning in the air – it's neither heads nor tails until it lands. A qubit is like that spinning coin, holding a probability of being 0 and a probability of being 1. This allows quantum computers to explore many possibilities at once.\n*   **Entanglement:** This is another mind-bending quantum phenomenon. When two or more qubits are entangled, they become interconnected in such a way that the state of one qubit instantly influences the state of the others, regardless of the distance between them. This creates powerful correlations that can be exploited for computation.\n\n**2. How Quantum Computers Work (Simplified)**\n\nInstead of performing operations on individual bits sequentially, quantum computers manipulate qubits in their superposition and entangled states. By applying a series of quantum operations (called **quantum gates**), they can:\n\n*   **Explore a vast number of possibilities simultaneously:** Because of superposition, a quantum computer with `n` qubits can represent $2^n$ states at once. This exponential increase in computational power is what makes quantum computers potentially so much faster for certain problems.\n*   **Discover patterns and solutions that are intractable for classical computers:** Entanglement allows for complex correlations between qubits, enabling the exploration of intricate relationships within data.\n\n**3. What Makes Quantum Computing Different from Classical Computing?**\n\n| Feature        | Classical Computers                               | Quantum Computers                                     |\n| :------------- | :------------------------------------------------ | :---------------------------------------------------- |\n| **Information Unit** | Bit (0 or 1)                                      | Qubit (0, 1, or a superposition of both)              |\n| **State Representation** | Discrete, definite states                         | Continuous, probabilistic states                      |\n| **Operations** | Logic gates (AND, OR, NOT)                       | Quantum gates (Hadamard, CNOT, etc.)                  |\n| **Problem Solving** | Solves problems step-by-step, sequentially        | Explores many possibilities simultaneously (parallelism) |\n| **Underlying Principles** | Classical physics                                 | Quantum mechanics (superposition, entanglement)       |\n\n**4. What Can Quantum Computers Do? (Potential Applications)**\n\nWhile still in its early stages, quantum computing holds the promise of revolutionizing many fields:\n\n*   **Drug Discovery and Materials Science:** Simulating molecular interactions with unprecedented accuracy, leading to the design of new drugs, catalysts, and advanced materials.\n*   **Financial Modeling:** Developing more sophisticated risk analysis, portfolio optimization, and fraud detection algorithms.\n*   **Cryptography:** Breaking current encryption methods (like RSA) and developing new, quantum-resistant encryption.\n*   **Artificial Intelligence and Machine Learning:** Accelerating training of complex AI models, improving pattern recognition, and enabling new AI capabilities.\n*   **Optimization Problems:** Solving complex logistical challenges in areas like transportation, supply chain management, and resource allocation.\n*   **Scientific Research:** Advancing fundamental understanding in physics, chemistry, and other scientific disciplines.\n\n**5. Challenges and the Current State of Quantum Co ...
